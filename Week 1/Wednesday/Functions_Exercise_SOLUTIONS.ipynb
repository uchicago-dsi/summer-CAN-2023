# %%
#import the basics!

import numpy as np
import pandas as pd

# %% [markdown]
# ### <mark style="background-color: Thistle">Working with DataFrame Functions: Activity!</mark>

# %% [markdown]
# Consider the Mental health data below. This Data set was collected by a survey conducted by Google forms from University students in order to examine their current academic situation and mental health.

# %%
Mental_health_df = pd.read_csv("https://raw.githubusercontent.com/SusannaLange/Data_118_images/main/DSSI_images/Student%20Mental%20health.csv")
Mental_health_df.head(5)
# Out:
#         Timestamp Choose your gender   Age What is your course?
# 0  8/7/2020 12:02             Female  18.0          Engineering  \
# 1  8/7/2020 12:04               Male  21.0    Islamic education
# 2  8/7/2020 12:05               Male  19.0                  BIT
# 3  8/7/2020 12:06             Female  22.0                 Laws
# 4  8/7/2020 12:13               Male  23.0         Mathemathics
#
#   Your current year of Study What is your CGPA? Marital status
# 0                     year 1        3.00 - 3.49             No  \
# 1                     year 2        3.00 - 3.49             No
# 2                     Year 1        3.00 - 3.49             No
# 3                     year 3        3.00 - 3.49            Yes
# 4                     year 4        3.00 - 3.49             No
#
#   Do you have Depression? Do you have Anxiety? Do you have Panic attack?
# 0                     Yes                   No                       Yes  \
# 1                      No                  Yes                        No
# 2                     Yes                  Yes                       Yes
# 3                     Yes                   No                        No
# 4                      No                   No                        No
#
#   Did you seek any specialist for a treatment?
# 0                                           No
# 1                                           No
# 2                                           No
# 3                                           No
# 4                                           No

# %% [markdown]
# 1. Notice the column 'Your current year of Study has different input values: 'year 1' vs 'Year 1'. Print all unique entries for this column.

# %%
#code here

# %%
Mental_health_df['Your current year of Study'].unique()
# Out:
# array(['year 1', 'year 2', 'Year 1', 'year 3', 'year 4', 'Year 2',
#        'Year 3'], dtype=object)

# %% [markdown]
# 2. Create (or use a built-in) function that makes the case the same for all entries and apply it to column 'Your current year of Study'.

# %%
#code here

# %%
def lowercase(string):
    return string.lower()

Mental_health_df['Your current year of Study'] = Mental_health_df['Your current year of Study'].apply(lowercase)

# %%
Mental_health_df['Your current year of Study'].unique()
# Out:
# array(['year 1', 'year 2', 'year 3', 'year 4'], dtype=object)

# %% [markdown]
# 3. We want to determine how many students answered 'Yes' to at least one of 'Do you have Depression?', 'Do you have Anxiety?', or 'Do you have Panic Attack?'. Create a new column called "Identified as having Depression, Anxiety, or Panic attacks", then sum over this column to relay this information.

# %%
def count_true(row):
    '''Returns 0 or 1 dependent on how if a student has at least one of depression, anxiety, or panic attacks'''
    count = 0
    
    if row["Do you have Depression?"]=='Yes':
        count = count +1
        
    if row["Do you have Anxiety?"] =='Yes':
        count = count +1
        
    if row["Do you have Panic attack?"] =='Yes':
        count = count +1
        
    if count >= 1:
        return True
    else:
        return False
        
##Option 2

def count_true_option2(row):
    '''Returns 0 or 1 dependent on how if a student has at least one of depression, anxiety, or panic attacks'''
 
    if row["Do you have Depression?"]=='Yes' or row["Do you have Anxiety?"] =='Yes' or row["Do you have Panic attack?"] =='Yes':
           return True
    else:
        return False

# %%
Mental_health_df["Identified as having Depression, Anxiety, or Panic attacks"] = Mental_health_df[["Do you have Depression?", "Do you have Anxiety?", 'Do you have Panic attack?']].apply(count_true, axis=1)

# %%
Mental_health_df
# Out:
#                Timestamp Choose your gender   Age What is your course?
# 0         8/7/2020 12:02             Female  18.0          Engineering  \
# 1         8/7/2020 12:04               Male  21.0    Islamic education
# 2         8/7/2020 12:05               Male  19.0                  BIT
# 3         8/7/2020 12:06             Female  22.0                 Laws
# 4         8/7/2020 12:13               Male  23.0         Mathemathics
# ..                   ...                ...   ...                  ...
# 96   13/07/2020 19:56:49             Female  21.0                  BCS
# 97   13/07/2020 21:21:42               Male  18.0          Engineering
# 98   13/07/2020 21:22:56             Female  19.0             Nursing
# 99   13/07/2020 21:23:57             Female  23.0     Pendidikan Islam
# 100  18/07/2020 20:16:21               Male  20.0   Biomedical science
#
#     Your current year of Study What is your CGPA? Marital status
# 0                       year 1        3.00 - 3.49             No  \
# 1                       year 2        3.00 - 3.49             No
# 2                       Year 1        3.00 - 3.49             No
# 3                       year 3        3.00 - 3.49            Yes
# 4                       year 4        3.00 - 3.49             No
# ..                         ...                ...            ...
# 96                      year 1        3.50 - 4.00             No
# 97                      Year 2        3.00 - 3.49             No
# 98                      Year 3        3.50 - 4.00            Yes
# 99                      year 4        3.50 - 4.00             No
# 100                     Year 2        3.00 - 3.49             No
#
#     Do you have Depression? Do you have Anxiety? Do you have Panic attack?
# 0                       Yes                   No                       Yes  \
# 1                        No                  Yes                        No
# 2                       Yes                  Yes                       Yes
# 3                       Yes                   No                        No
# 4                        No                   No                        No
# ..                      ...                  ...                       ...
# 96                       No                  Yes                        No
# 97                      Yes                  Yes                        No
# 98                      Yes                   No                       Yes
# 99                       No                   No                        No
# 100                      No                   No                        No
#
#     Did you seek any specialist for a treatment?
# 0                                             No  \
# 1                                             No
# 2                                             No
# 3                                             No
# 4                                             No
# ..                                           ...
# 96                                            No
# 97                                            No
# 98                                            No
# 99                                            No
# 100                                           No
#
#      Identified as having Depression, Anxiety, or Panic attacks
# 0                                                 True
# 1                                                 True
# 2                                                 True
# 3                                                 True
# 4                                                False
# ..                                                 ...
# 96                                                True
# 97                                                True
# 98                                                True
# 99                                               False
# 100                                              False
#
# [101 rows x 12 columns]

# %%
sum(Mental_health_df["Identified as having Depression, Anxiety, or Panic attacks"])
# Out:
# 64
